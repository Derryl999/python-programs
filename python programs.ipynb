# %%
num1 = int(input('enter an integer: '))
num2 = float(input('enter a floating point number: '))


print('The numbers are: ',num1,' and ',num2)
print('Their sum is: ',num1+num2, 'Their product is:',num1*num2)
# Out:
# enter an integer: 10
# enter a floating point number: 20.5
# The numbers are:  10  and  20.5
# Their sum is:  30.5 Their product is: 205.0

# %%
num1Str = input(' enter an integer: ')
num2Str = input(' enter a second integer: ')

num1 = int(num1Str)
num2 = int(num2Str)

print ('num1','plus','num2','equals',num1+num2)
# Out:
#  enter an integer: 10
#  enter a second integer: 20
# num1 plus num2 equals 30

# %%
import math

#math.pi
print("value of math.pi is:",math.pi)

#round function
print( "Result of round(math.pi):", round(math.pi))
print( "Result of round(math.pi):", round(math.pi,5))


count_str = input( "Enter a count (an integer number):" )
length_str = input( "Enter a length (a floating point number):" )

count = int( count_str )

length = float( length_str )

print( "count:", count )
print( "length:", length )

print( "The area of", count, "squares is", 4*length**2, "sq units." )

price = 5.68

print( "Price:", price )
print( "Price as an integer:", int(price) )
# Out:
# value of math.pi is: 3.141592653589793
# Result of round(math.pi): 3
# Result of round(math.pi): 3.14159
# Enter a count (an integer number):10
# Enter a length (a floating point number):20.5
# count: 10
# length: 20.5
# The area of 10 squares is 1681.0 sq units.
# Price: 5.68
# Price as an integer: 5

# %%
import math

intStr1 = input('Enter an integer: ')
floatStr2 = input('Enter a floating point number: ')

int1 = int(intStr1)

float1 = float(floatStr2)


print('Result of int1+5: ', int1+5)
print('Result of int1*int1: ', int1*int1) 
print('Result of float1+float1: ', float1+float1)
print('Result of float1*int1: ', float1*int1)
print('Result of int1/float1 is: ', int1/float1)
print('Result of int1/2 is: ', int1/3)

float2 = 3.516
print('Result of float2: ', float2)
print('Result of int(float2): ', int(float2))

#math.trunc
print('Result of math.trunc(float2): ', math.trunc(float2))

#round
print('Result of round(float2): ', round(float2))
print('Result of round(float2,1): ', round(float2,1))
# Out:
# Enter an integer: 10
# Enter a floating point number: 2.2
# Result of int1+5:  15
# Result of int1*int1:  100
# Result of float1+float1:  4.4
# Result of float1*int1:  22.0
# Result of int1/float1 is:  4.545454545454545
# Result of int1/2 is:  3.3333333333333335
# Result of float2:  3.516
# Result of int(float2):  3
# Result of math.trunc(float2):  3

# %%
# 1. Elon's dictionary
elon = { "name":"Elon  Musk",
         "assignment" : [82, 60, 55, 30],
         "test" : [75, 75],
         "lab" : [78.20, 77.20]
       }
        
# 2. Bill's dictionary
bill = { "name":"Bill Gates",
          "assignment" : [85, 65, 44, 30],
          "test" : [80, 80],
          "lab" : [67.90, 78.72]
        }
 
# 3. Derryl's dictionary
derryl = { "name" : "Derryl Ashwin",
          "assignment" : [78, 82, 23, 39],
          "test" : [68, 72],
          "lab" : [79, 80]
        }
         
# 4. Jeff's dictionary
jeff = { "name" : "Jeff Bezoz",
         "assignment" : [67, 55, 77, 21],
         "test" : [40, 50],
         "lab" : [69, 44.56]
       }
        
# 5. Mukesh's dictionary
mukesh = { "name" : "Mukesh Ambani",
        "assignment" : [29, 89, 60, 56],
        "test" : [65, 56],
        "lab" : [50, 40.6]
      }

def get_average(marks):
    total_sum = sum(marks)
    total_sum = float(total_sum)
    return total_sum / len(marks)
 

def calculate_total_average(students):
    assignment = get_average(students["assignment"])
    test = get_average(students["test"])
    lab = get_average(students["lab"])

    return (0.1 * assignment + 0.7 * test + 0.2 * lab)
 
 
# Calculate letter grade of each student
def assign_letter_grade(score):
    if score >= 90: return "A"
    elif score >= 80: return "B"
    elif score >= 70: return "C"
    elif score >= 60: return "D"
    else : return "E"
 

def class_average_is(student_list):
    result_list = []
 
    for student in student_list:
        stud_avg = calculate_total_average(student)
        result_list.append(stud_avg)
        return get_average(result_list)
 

students = [elon,bill,derryl,jeff,mukesh]

for i in students :
    print(i["name"])
    print("________________________________________")
    
    avg_marks=calculate_total_average(i)
    print("Average marks of %s is : %s " %(i["name"],avg_marks))
                          
    print("Letter Grade of %s is : %s" %(i["name"],
    assign_letter_grade(avg_marks)))
     
    print()
 
 

class_av = class_average_is(students)
 
print( "Class Average is %s" %(class_av))
print("Letter Grade of the class is %s " %(assign_letter_grade(class_av)))
# Out:
# Elon  Musk
# ________________________________________
# Average marks of Elon  Musk is : 73.715
# Letter Grade of Elon  Musk is : C
#
# Bill Gates
# ________________________________________
# Average marks of Bill Gates is : 76.262
# Letter Grade of Bill Gates is : C
#
# Derryl Ashwin
# ________________________________________
# Average marks of Derryl Ashwin is : 70.45
# Letter Grade of Derryl Ashwin is : C
#
# Jeff Bezoz
# ________________________________________
# Average marks of Jeff Bezoz is : 48.356
# Letter Grade of Jeff Bezoz is : E
#
# Mukesh Ambani
# ________________________________________
# Average marks of Mukesh Ambani is : 57.26
# Letter Grade of Mukesh Ambani is : E
#
# Class Average is 73.715
# Letter Grade of the class is C

# %%
import string
import random
import time

possibleCharacters = string.ascii_lowercase + string.digits +string.ascii_uppercase + ' ., !?;:'
 
# string to be generated
t = "Hello"

 
attemptThis = ''.join(random.choice(possibleCharacters)
                                for i in range(len(t)))
attemptNext = ''
 
completed = False
iteration = 0

while completed == False:
    print(attemptThis)
     
    attemptNext = ''
    completed = True
     

    for i in range(len(t)):
        if attemptThis[i] != t[i]:
            completed = False
            attemptNext += random.choice(possibleCharacters)
        else:
            attemptNext += t[i]
             
    # increment the iteration 
    iteration += 1
    attemptThis = attemptNext
    time.sleep(0.1)
 

print("Target matched after " +
      str(iteration) + " iterations")
# Out:
# !vGWB
# ST8eJ
# KkT0!
# C6?wf
# x A9d
# QswfN
# 2a1a2
# MRc R
#  D6yP
#  gW93
# YX?0Q
# !Yp9K
#  gXG.
# Xcphl
# QezVI
# ?eXWK
# keRvz
# IeS7m
# :es.!
# SeIIw
# :eOom
# Der,2
# BecC8
# Jepvt
# 9eA:D
# Qe0Bb
# beMuu
# senP8
# KeJi?
# .eWGs
# vehCn
# JeLw0
# 7eUfV
# YeG1I
# Qe? p
# fe;YX
# UeNqS
# ve6:p
# ee4Xe
# HeDR?
# HeP?l
# HeOnH
# HehHj
# He3RK
# HeECI
# He3tF
# HeJ1J
# HeJhL
# HeU!B
# HeAw4
# He,y;
# HeE?X
# HeR7C
# He!ZG
# HeiEO
# He9ee
# HejiK
# He zZ
# HewCU
# He,,D
# He91U
# He6IX
# Hez:i
# He0Uj
# Hevsy
# HeoMh
# He p5
# HeXz
# HeY0p
# HeQCe
# HeJXb
# HeKTj
# HeU.4
# HeeQg
# HeA0x
# He,OA
# Het?W
# He9Xb
# Hec8:
# HeKSE
# He m?
# He6dO
# HeXjL
# HeoNL
# HeG,D
# HevsJ
# HesnT
# HeY,K
# HeOsv
# HeRY;
# He01p
# Heghr
# HeXJt
# HeH1z
# Hepmj
# HeXVl
# HetAY
# HeKVE
# HebpG
# HebP
# Heqvy
# HeIEN
# He..h
# HeXvI
# HeFfW
# HelRP
# Helv?
# HelYr
# HelE9
# HelTq
# Helg7
# HelzP
# HelXD
# HelX1
# Helw.
# Helsi
# HelP2
# HelRH
# Hel5y
# Hel01
# HelBT
# Helhl
# Helua
# Hel!,
# HelcB
# HelEs
# HelrI
# Hel9.
# HelYz
# Hel:
# HelD5
# Hel a
# HelFS
# Helq0
# Hel73
# HeldQ
# Hel?6
# HelY2
# HelVq
# Helh7
# HelTF
# HelJ3
# Helwb
# HelXJ
# HelxT
# HelQT
# HelLW
# Hel.w
# HelR
# HelOE
# HelSz
# Helj:
# Heln3
# HelyI
# HelUY
# Hela1
# HeluF
# HelFc
# Helxw
# HelK3
# Helnt
# Hel5Y
# HelZB
# HeliI
# Hel4G
# Hel9U
# HelX9
# Hel0M
# HelQv
# HelQ6
# Helj:
# Hel5M
# Helah
# HelJY
# Helke
# HelqQ
# HelwG
# Hel:g
# Helw:
# HelFX
# HelTS
# HelLt
# HelnI
# Hel m
# HelL
# HelTe
# HelwD
# HelFG
# Hel6K
# HelN,
# HelXU
# HelLg
# Hel61
# Hel.1
# HelYH
# Helyt
# Hel.O
# HelM
# Hel.
# HelXy
# HelY9
# HelnM
# HelCa
# Hel0c
# HelPP
# HelqB
# HelQQ
# Heln!
# HelHm
# HelzG
# HelHm
# HelP4
# Held,
# HelFX
# HelsD
# Helo8
# Helap
# HelX8
# Helvt
# Hel3G
# Helh2
# HelmY
# Hel,E
# HelKr
# HelBm
# Hel,b
# HelVr
# Hel.P
# Helml
# Helnr
# Hel;:
# Hel 3
# Hellt
# HellQ
# Hell7
# Hellm
# HellL
# Hellv
# Hell8
# Hellh
# Hell1
# Hellh
# HellT
# Helli
# Hell6
# Hellt
# Hells
# Hello
# Target matched after 248 iterations

# %%
name = "DERRYL"
 

 
lngth = len(name)
l = ""
 
for x in range(0, lngth):
    c = name[x]
    c = c.upper()
     
    if (c == "A"):
        print("..######..\n..#....#..\n..######..", end = " ")
        print("\n..#....#..\n..#....#..\n\n")
         
    elif (c == "B"):
        print("..######..\n..#....#..\n..#####...", end = " ")
        print("\n..#....#..\n..######..\n\n")
         
    elif (c == "C"):
        print("..######..\n..#.......\n..#.......", end = " ")
        print("\n..#.......\n..######..\n\n")
         
    elif (c == "D"):
        print("..#####...\n..#....#..\n..#....#..", end = " ")
        print("\n..#....#..\n..#####...\n\n")
         
    elif (c == "E"):
        print("..######..\n..#.......\n..#####...", end = " ")
        print("\n..#.......\n..######..\n\n")
         
    elif (c == "F"):
        print("..######..\n..#.......\n..#####...", end = " ")
        print("\n..#.......\n..#.......\n\n")
         
    elif (c == "G"):
        print("..######..\n..#.......\n..#.####..", end = " ")
        print("\n..#....#..\n..#####...\n\n")
         
    elif (c == "H"):
        print("..#....#..\n..#....#..\n..######..", end = " ")
        print("\n..#....#..\n..#....#..\n\n")
         
    elif (c == "I"):
        print("..######..\n....##....\n....##....", end = " ")
        print("\n....##....\n..######..\n\n")
         
    elif (c == "J"):
        print("..######..\n....##....\n....##....", end = " ")
        print("\n..#.##....\n..####....\n\n")
         
    elif (c == "K"):
        print("..#...#...\n..#..#....\n..##......", end = " ")
        print("\n..#..#....\n..#...#...\n\n")
         
    elif (c == "L"):
        print("..#.......\n..#.......\n..#.......", end = " ")
        print("\n..#.......\n..######..\n\n")
         
    elif (c == "M"):
        print("..#....#..\n..##..##..\n..#.##.#..", end = " ")
        print("\n..#....#..\n..#....#..\n\n")
         
    elif (c == "N"):
        print("..#....#..\n..##...#..\n..#.#..#..", end = " ")
        print("\n..#..#.#..\n..#...##..\n\n")
         
    elif (c == "O"):
        print("..######..\n..#....#..\n..#....#..", end = " ")
        print("\n..#....#..\n..######..\n\n")
         
    elif (c == "P"):
        print("..######..\n..#....#..\n..######..", end = " ")
        print("\n..#.......\n..#.......\n\n")
         
    elif (c == "Q"):
        print("..######..\n..#....#..\n..#.#..#..", end = " ")
        print("\n..#..#.#..\n..######..\n\n")
         
    elif (c == "R"):
        print("..######..\n..#....#..\n..#.##...", end = " ")
        print("\n..#...#...\n..#....#..\n\n")
         
    elif (c == "S"):
        print("..######..\n..#.......\n..######..", end = " ")
        print("\n.......#..\n..######..\n\n")
         
    elif (c == "T"):
        print("..######..\n....##....\n....##....", end = " ")
        print("\n....##....\n....##....\n\n")
         
    elif (c == "U"):
        print("..#....#..\n..#....#..\n..#....#..", end = " ")
        print("\n..#....#..\n..######..\n\n")
         
    elif (c == "V"):
        print("..#....#..\n..#....#..\n..#....#..", end = " ")
        print("\n...#..#...\n....##....\n\n")
         
    elif (c == "W"):
        print("..#....#..\n..#....#..\n..#.##.#..", end = " ")
        print("\n..##..##..\n..#....#..\n\n")
         
    elif (c == "X"):
        print("..#....#..\n...#..#...\n....##....", end = " ")
        print("\n...#..#...\n..#....#..\n\n")
         
    elif (c == "Y"):
        print("..#....#..\n...#..#...\n....##....", end = " ")
        print("\n....##....\n....##....\n\n")
         
    elif (c == "Z"):
        print("..######..\n......#...\n.....#....", end = " ")
        print("\n....#.....\n..######..\n\n")
         
    elif (c == " "):
        print("..........\n..........\n..........", end = " ")
        print("\n..........\n\n")
         
    elif (c == "."):
        print("----..----\n\n")
# Out:
# ..#####...
# ..#....#..
# ..#....#..
# ..#....#..
# ..#####...
#
#
# ..######..
# ..#.......
# ..#####...
# ..#.......
# ..######..
#
#
# ..######..
# ..#....#..
# ..#.##...
# ..#...#...
# ..#....#..
#
#
# ..######..
# ..#....#..
# ..#.##...
# ..#...#...
# ..#....#..
#
#
# ..#....#..
# ...#..#...
# ....##....
# ....##....
# ....##....
#
#
# ..#.......
# ..#.......
# ..#.......
# ..#.......
# ..######..

# %%
# addition
def add(x, y):
   return x + y

# subtraction 
def subtract(x, y):
   return x - y

# multiplication
def multiply(x, y):
   return x * y

# division
def divide(x, y):
   return x / y

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")


choice = input("Enter choice(1/2/3/4):")

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

if choice == '1':
   print(num1,"+",num2,"=", add(num1,num2))

elif choice == '2':
   print(num1,"-",num2,"=", subtract(num1,num2))

elif choice == '3':
   print(num1,"*",num2,"=", multiply(num1,num2))

elif choice == '4':
   print(num1,"/",num2,"=", divide(num1,num2))
else:
   print("Invalid input")
# Out:
# Select operation.
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# Enter choice(1/2/3/4):1
# Enter first number: 10
# Enter second number: 20
# 10 + 20 = 30
